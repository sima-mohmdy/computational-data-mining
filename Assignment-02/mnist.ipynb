# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
import os
from skimage.io import imread_collection
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sn

# %% [markdown]
# # read images of train data from folder

# %% [markdown]
# unzip rar file

# %%
pip install patool

# %%
# unzip rar file
#pip install patool
#import patoolib
#patoolib.extract_archive("/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST.rar", outdir="/content/drive/MyDrive/ML/computational data mining/تمرین دوم")

# %% [markdown]
# count files in a folder

# %%
# count files in whole folder
file_count = sum(len(files) for _, _, files in os.walk('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST'))
print(file_count)
# Out:
# 4600

# %%
# count files in train folder
file_count = sum(len(files) for _, _, files in os.walk('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train'))
print(file_count)
# Out:
# 3998

# %%
# count files in test folder
file_count = sum(len(files) for _, _, files in os.walk('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/test'))
print(file_count)
# Out:
# 600

# %%
train0 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/0/*.jpg')
train1 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/1/*.jpg')
train2 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/2/*.jpg')
train3 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/3/*.jpg')
train4 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/4/*.jpg')
train5 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/5/*.jpg')
train6 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/6/*.jpg')
train7 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/7/*.jpg')
train8 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/8/*.jpg')
train9 = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train/9/*.jpg')

# %% [markdown]
# shape of each classes

# %%
# shape of each classes
#print('shape of class 0 =', np.shape(train0))
#print('shape of class 1 =', np.shape(train1))
#print('shape of class 2 =', np.shape(train2))
#print('shape of class 3 =', np.shape(train3))
#print('shape of class 4 =', np.shape(train4))
#print('shape of class 5 =', np.shape(train5))
#print('shape of class 6 =', np.shape(train6))
#print('shape of class 7 =', np.shape(train7))
#print('shape of class 8 =', np.shape(train8))
#print('shape of class 9 =', np.shape(train9))

# %% [markdown]
# type of each classes

# %%
# type of each classes
print('type of class 0 =', type(train0[0]))
print('type of class 1 =', type(train1[0]))
print('type of class 2 =', type(train2[0]))
print('type of class 3 =', type(train3[0]))
print('type of class 4 =', type(train4[0]))
print('type of class 5 =', type(train5[0]))
print('type of class 6 =', type(train6[0]))
print('type of class 7 =', type(train7[0]))
print('type of class 8 =', type(train8[0]))
print('type of class 9 =', type(train9[0]))
# Out:
# type of class 0 = <class 'numpy.ndarray'>
# type of class 1 = <class 'numpy.ndarray'>
# type of class 2 = <class 'numpy.ndarray'>
# type of class 3 = <class 'numpy.ndarray'>
# type of class 4 = <class 'numpy.ndarray'>
# type of class 5 = <class 'numpy.ndarray'>
# type of class 6 = <class 'numpy.ndarray'>
# type of class 7 = <class 'numpy.ndarray'>
# type of class 8 = <class 'numpy.ndarray'>
# type of class 9 = <class 'numpy.ndarray'>

# %% [markdown]
# # Show some images as example

# %%
train = [train0, train1, train2, train3, train4, train5, train6, train7, train8, train9]

for i in range(len(train)):
    plt.subplot(2, 5, i + 1)
    plt.imshow(train[i][0], cmap='gray')
    plt.title(f"Label: Digit{i}")

plt.tight_layout()
plt.show()

# %% [markdown]
# # calculate mean of each classes of train data

# %%
# calculate mean of each classes of train data
train = [train0, train1, train2, train3, train4, train5, train6, train7, train8, train9]

mean_list = []
for i in range(len(train)):
  mean= np.mean(train[i], axis=0)
  mean_list.append(mean)
  print(f'mean of train{i} is: {mean.shape}')

print('-' * 30)
#print('mean list is: ', mean_list)
print('len of mean list is: ', len(mean_list))
# Out:
# mean of train0 is: (28, 28)
# mean of train1 is: (28, 28)
# mean of train2 is: (28, 28)
# mean of train3 is: (28, 28)
# mean of train4 is: (28, 28)
# mean of train5 is: (28, 28)
# mean of train6 is: (28, 28)
# mean of train7 is: (28, 28)
# mean of train8 is: (28, 28)
# mean of train9 is: (28, 28)
# ------------------------------
# len of mean list is:  10

# %% [markdown]
# Show mean images of each classes of train data

# %%
# Show mean images of each classes of train data
train = [train0, train1, train2, train3, train4, train5, train6, train7, train8, train9]

for i in range(len(train)):
  mean= np.mean(train[i], axis=0)
  plt.subplot(2, 5, i + 1)
  plt.imshow(mean, cmap='gray')
  plt.title(f"Label: mean{i}")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Read & Check test data

# %% [markdown]
# read test data from folder

# %%
# read test data from folder
test = imread_collection('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/test/test/*.jpg')

print(type(test[0]))
np.shape(test[0])
# Out:
# <class 'numpy.ndarray'>
# (28, 28)

# %% [markdown]
# show 10 first digits of test data

# %%
# show 10 first digits of test data
for i in range(10):

    plt.subplot(2, 5, i + 1)
    plt.imshow(test[i], cmap='gray')
    #plt.title(f"Label: Digit{i}")
    #plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # flatten (vectorize) dataset

# %% [markdown]
# flatten (vctorize) means of classes of train data

# %%
for img in test:
  # Flattening the array
  flattened_img = img.flatten()
  #print(f'Shape of flatten image is: {np.shape(flattened_img)}')

print(f'Shape of flatten image is: {np.shape(flattened_img)}')
# Out:
# Shape of flatten image is: (784,)

# %%
#mean_list

# %%
len(mean_list)
# Out:
# 10

# %%
np.shape(mean_list[0])
# Out:
# (28, 28)

# %%
mean_list_flatten = []
for m in mean_list:
  # Flattening the array
  flattened_mean = m.flatten()
  mean_list_flatten.append(flattened_mean)
  print(f'Shape of flatten image is: {np.shape(flattened_mean)}')

print('-'*30)
#print('flatten of mean list: ', mean_list_flatten)
print('len of flatten mean list: ', len(mean_list_flatten))
# Out:
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# Shape of flatten image is: (784,)
# ------------------------------
# len of flatten mean list:  10

# %% [markdown]
# # find min euclidean distance between two vectors of test data & means of each classes in train data

# %%
predicted_labels = []

for img in test:
  # Flattening image in test data
  flattened_img = img.flatten()

  distance = []
  for m in mean_list:
    # Flattening mean of train data
    flattened_mean = m.flatten()

    # Calulate Euclidean distance
    d = np.linalg.norm(flattened_img - flattened_mean)

    distance.append(d)

  predicted_labels.append(np.argmin(distance))


#print('predicted labels is: ', predicted_labels)
print('predicted labels is: ', len(predicted_labels))
# Out:
# predicted labels is:  600

# %%
len(predicted_labels)
# Out:
# 600

# %% [markdown]
# # Calculate Accuracy

# %% [markdown]
# read train labels (in given csv file)

# %%
# # read train labels (in given csv file)
train_labels = pd.read_csv('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/train labels.csv')
train_labels
# Out:
#          id  category
# 0     37172         5
# 1     37180         5
# 2     37185         5
# 3     37206         5
# 4     37208         5
# ...     ...       ...
# 3995  41995         0
# 3996  41996         1
# 3997  41997         7
# 3998  41998         6
# 3999  41999         9
#
# [4000 rows x 2 columns]

# %% [markdown]
# read test labels (in given csv file)

# %%
# # read test labels (in given csv file)
test_labels = pd.read_csv('/content/drive/MyDrive/ML/computational data mining/تمرین دوم/TinyMNIST/test labels.csv')
test_labels
# Out:
#       id  category
# 0      0         1
# 1      1         0
# 2      2         1
# 3      3         4
# 4      4         0
# ..   ...       ...
# 595  653         8
# 596  654         7
# 597  659         6
# 598  672         8
# 599  674         8
#
# [600 rows x 2 columns]

# %%
len(predicted_labels)
# Out:
# 600

# %%
len(test_labels['category'])
# Out:
# 600

# %% [markdown]
# Using accuracy_score function

# %%
# Using accuracy_score function
print(accuracy_score(test_labels['category'], predicted_labels)* 100)
# Out:
# 79.5

# %%
y_test, y_pred = test_labels['category'], predicted_labels

# %%
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91        60
#            1       0.69      0.93      0.79        60
#            2       0.95      0.70      0.81        60
#            3       0.69      0.83      0.76        60
#            4       0.81      0.83      0.82        60
#            5       0.73      0.60      0.66        60
#            6       0.86      0.83      0.85        60
#            7       0.91      0.72      0.80        60
#            8       0.76      0.78      0.77        60
#            9       0.72      0.83      0.78        60
#
#     accuracy                           0.80       600
#    macro avg       0.81      0.79      0.80       600
# weighted avg       0.81      0.80      0.80       600

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[53  0  0  1  0  4  1  0  1  0]
#  [ 0 56  0  0  0  1  1  0  2  0]
#  [ 1  5 42  2  3  0  3  1  3  0]
#  [ 0  2  1 50  1  3  0  1  1  1]
#  [ 0  1  0  0 50  0  1  0  1  7]
#  [ 1  7  0 11  1 36  2  0  1  1]
#  [ 0  4  0  0  3  2 50  0  1  0]
#  [ 0  3  1  0  2  0  0 43  3  8]
#  [ 0  2  0  7  0  2  0  0 47  2]
#  [ 1  1  0  1  2  1  0  2  2 50]]

# %%
df_cm = pd.DataFrame(conf_matrix, range(10), range(10))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size

plt.show()
